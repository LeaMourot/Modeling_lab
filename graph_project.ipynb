= {
    'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2],
    'pressure_unit': 'bar', 
    'loading_absolute_dev': [0.016993090008819, 0.083292720037352, 0.08070170961316, 0.15307915555637, 0.094663259005052, 0.12600803337052, 0.093450108445972, 0.19973120446116, 0.07856851686949, 0.16752161134162, 0.14393370317449, 0.14825684903336, 0.24229073845879, 0.1137731285993, 0.1052134801731, 0.26486121310362, 0.092081482076836, 0.26199877460714],
    'loading_absolute_unit': 'mol/kg', 
    'loading_absolute_average': [0.31424485381695, 1.1580909367748, 2.038693985348, 2.9664843410745, 3.8041249233618, 4.7398294176147, 5.6300892453135, 6.571769721719, 7.5454467796638, 8.1926294954818, 9.0655394233608, 9.9333829424732, 10.499469115282, 11.176310724031, 11.800907117546, 12.322322186213, 12.73597406036, 13.056237399758],

}

data_C02_ZIF_8 = {
    'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2], 
    'pressure_unit': 'bar', 
    'loading_absolute_dev': [0.010073555904033, 0.023498820796776, 0.044495885986833, 0.083627300420311, 0.048057990841905, 0.10971861719071, 0.10627134008481, 0.13765836320995, 0.087492726327806, 0.13497869704525, 0.088921203142253, 0.12607651835773, 0.121634611336, 0.22601827443966, 0.139893031338, 0.20181218855511, 0.20111112449173, 0.093057956919987],
    'loading_absolute_unit': 'mol/kg', 
    'loading_absolute_average': [0.16863404693292, 0.7170356655534, 1.227697601413, 1.8236514033812, 2.4540954126362, 2.9938836328871, 3.5469992793082, 4.0608374630256, 4.4329985160679, 4.8204000667568, 5.1898333910912, 5.4522903214342, 5.7803317356437, 5.993213569738, 6.221143678986, 6.3982355156039, 6.5196102896543, 6.6732784425018]
    
}
# Création de la figure
fig, ax1 = plt.subplots()

# Tracé de la charge absolue CO2 en fonction de la pression
ax1.errorbar(data_CO2_Mg_MOF_74['pressure'], data_CO2_Mg_MOF_74['loading_absolute_average'], yerr=data_CO2_Mg_MOF_74['loading_absolute_dev'], fmt='-o', color='b', label='CO2 Loading for Mg MOF-74 (mol/kg)')
# Tracé de la charge absolue C02 en fonction de la pression
ax1.errorbar(data_C02_NOTT_300['pressure'], data_C02_NOTT_300['loading_absolute_average'], yerr=data_C02_NOTT_300['loading_absolute_dev'], fmt='-o', color='r', label='CO2 Loading for NOTT-300 (mol/kg)')
# Tracé de la charge absolue C02 en fonction de la pression
ax1.errorbar(data_C02_UTSA_20['pressure'], data_C02_UTSA_20['loading_absolute_average'], yerr=data_C02_UTSA_20['loading_absolute_dev'], fmt='-o', color='g', label='CO2 Loading for UTSA-20 (mol/kg)')
# Tracé de la charge absolue CO2 en fonction de la pression
ax1.errorbar(data_C02_UTSA_80['pressure'], data_C02_UTSA_80['loading_absolute_average'], yerr=data_C02_UTSA_80['loading_absolute_dev'], fmt='-o', color='orange', label='CO2 Loading for UTSA-80 (mol/kg)')
# Tracé de la charge absolue CO2 en fonction de la pression
ax1.errorbar(data_C02_ZIF_8['pressure'], data_C02_ZIF_8['loading_absolute_average'], yerr=data_C02_ZIF_8['loading_absolute_dev'], fmt='-o', color='c', label='CO2 Loading for ZIF-8 (mol/kg)')


# Paramètres des axes
ax1.set_xlabel(f"Pressure ({data_CO2_Mg_MOF_74['pressure_unit']})")
ax1.set_ylabel(f"Loading Absolute ({data_CO2_Mg_MOF_74['loading_absolute_unit']})")

# Légendes et affichage
ax1.legend()
plt.title("CO2 pure Isotherms at 298K for different MOFs ")
plt.show()

# %%
import matplotlib.pyplot as plt

# Données fournies pour CO2 et CH4 (exemple)
data_N2_Mg_MOF_74 = {
  'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2], 
    'loading_absolute_unit': 'mol/kg',
    'loading_absolute_average': [0.06563379544785, 0.26439683199255, 0.45816146525745, 0.62400984619095, 0.8023627360098, 0.97143287688045, 1.1356066227015, 1.3174702957764, 1.4491204175354, 1.6241835419303, 1.7920465854102, 1.9268249595619, 2.1054243692705, 2.239310171408, 2.337518595033, 2.5546176109562, 2.6749108164195, 2.7594671385695],
   
}


# Création de la figure
fig, ax1 = plt.subplots()

# Tracé de la charge absolue CO2 en fonction de la pression
ax1.errorbar(data_N2_Mg_MOF_74['pressure'], data_N2_Mg_MOF_74['loading_absolute_average'], yerr=data_N2_Mg_MOF_74['loading_absolute_dev'], fmt='-s', color='b', label='N2 Loading for Mg MOF-74 (mol/kg)')
# Tracé de la charge absolue C02 en fonction de la pression
ax1.errorbar(data_N2_NOTT_300['pressure'], data_N2_NOTT_300['loading_absolute_average'], yerr=data_N2_NOTT_300['loading_absolute_dev'], fmt='-s', color='r', label='N2 Loading for NOTT-300 (mol/kg)')
# Tracé de la charge absolue C02 en fonction de la pression
ax1.errorbar(data_N2_UTSA_20['pressure'], data_N2_UTSA_20['loading_absolute_average'], yerr=data_N2_UTSA_20['loading_absolute_dev'], fmt='-s', color='g', label='N2 Loading for UTSA-20 (mol/kg)')
# Tracé de la charge absolue CO2 en fonction de la pression
ax1.errorbar(data_N2_UTSA_80['pressure'], data_N2_UTSA_80['loading_absolute_average'], yerr=data_N2_UTSA_80['loading_absolute_dev'], fmt='-s', color='orange', label='N2 Loading for UTSA-80 (mol/kg)')


# Paramètres des axes
ax1.set_xlabel(f"Pressure ({data_N2_Mg_MOF_74['pressure_unit']})")
ax1.set_ylabel(f"Loading Absolute ({data_N2_Mg_MOF_74['loading_absolute_unit']})")

# Légendes et affichage
ax1.legend()
plt.title("N2 pure Isotherms at 298K for different MOFs ")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Données
selectivity = [8.08, 4.74, 4.59, 16.52]
WC = [0.3693, 0.1803, 0.1423, 1.5628]
materiaux = ["UTSA-20", "UTSA-80", "Mg-74", "NOTT-300"]

# Création du graphique
plt.figure(figsize=(8, 6))
plt.scatter(selectivity, WC, color='lime', marker='o', label='MOF')

# Annotation des points avec les noms des matériaux
for i, materiau in enumerate(materiaux):
    if i==1 :
        plt.text(selectivity[i], WC[i], materiau, fontsize=12, ha='left')
    elif i==2 :
          plt.text(selectivity[i], WC[i], materiau, fontsize=12, ha='center', va='top')
    else: 
        plt.text(selectivity[i], WC[i], materiau, fontsize=12, ha='right')
    

# Ajustement d'une courbe de tendance (régression linéaire)
z = np.polyfit(selectivity, WC, 1)
p = np.poly1d(z)

'''
# Affichage de la courbe de tendance
plt.plot(selectivity, p(selectivity), "r--", label='Courbe de tendance')
'''
# Titre et légendes
plt.title("Working Capacity vs Selectivity")
plt.xlabel("Selectivity ")
plt.ylabel("Working capacity [mol/Kg] ")

# Affichage de la légende et de la grille
plt.legend()
#plt.grid(True)
plt.show()
