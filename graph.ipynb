# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 12.3 MB/s eta 0:00:0000:0100:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# Données fournies
data = {
    'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2],
    'pressure_unit': 'bar',
    'loading_absolute_dev': [0.0029257587086246, 0.0046961432152114, 0.0042053747373354, 0.013539894417122, 0.013483719817968, 0.015161025526191, 0.010612737734106, 0.023253338259637, 0.034225174027897, 0.024345129716779, 0.030457062150504, 0.023879951201299, 0.031029028064904, 0.034006398430243, 0.038159936407652, 0.036657581075093, 0.024814842927216, 0.06009003342175],
    'loading_absolute_average': [0.021916150047, 0.086852890927, 0.15377020240384, 0.22218105892092, 0.29150102981032, 0.359587202623, 0.431017617591, 0.4899477099396, 0.55270907000012, 0.62823049964356, 0.68696578176952, 0.75144796546336, 0.82284591206092, 0.89326980754528, 0.9633365509548, 1.024669302716, 1.0889891445576, 1.1474971480905],
    'loading_absolute_unit': 'mol/kg',
    'enthalpy_of_adsorption_dev': [0.19905159096389, 0.18339598247321, 0.088397063347551, 0.10359254362991, 0.059716436773008, 0.13516628836065, 0.13055663365843, 0.14117760428359, 0.092710949257107, 0.09738388499497, 0.084694894115886, 0.1041281334963, 0.090457010301564, 0.096967332651551, 0.057348598604841, 0.10692105460078, 0.065425797976271, 0.16671084116967],
    'enthalpy_of_adsorption_average': [-5.8322569487749, -5.7872556600401, -5.8350490966385, -5.8120516657937, -5.9306484414623, -5.8687369567567, -5.9059838866579, -5.9081274267708, -5.967548410699, -5.9638010193477, -5.9192489586191, -5.9964504086536, -6.0172509208218, -6.0551921877728, -6.0778865580804, -6.0793115661869, -6.0856428292302, -6.0646085156269],
    'enthalpy_of_adsorption_unit': 'kJ/mol'
}

# Création de la figure
fig, ax1 = plt.subplots()

# Tracé de la charge absolue en fonction de la pression
ax1.errorbar(data['pressure'], data['loading_absolute_average'], yerr=data['loading_absolute_dev'], fmt='-o', color='b', label='Loading Absolute (mol/kg)')
ax1.set_xlabel(f"Pressure ({data['pressure_unit']})")
ax1.set_ylabel(f"Loading Absolute ({data['loading_absolute_unit']})", color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Ajout d'un deuxième axe pour l'enthalpie d'adsorption
'''
ax2 = ax1.twinx()
ax2.errorbar(data['pressure'], data['enthalpy_of_adsorption_average'], yerr=data['enthalpy_of_adsorption_dev'], fmt='-s', color='r', label='Enthalpy of Adsorption (kJ/mol)')
ax2.set_ylabel(f"Enthalpy of Adsorption ({data['enthalpy_of_adsorption_unit']})", color='r')
ax2.tick_params(axis='y', labelcolor='r')'''

# Légendes et affichage
fig.tight_layout()
plt.title("CH4 pure isotherm at 300K")
plt.show()

# %%
import matplotlib.pyplot as plt

# Nouvelles données fournies
data = {
    'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2],
    'pressure_unit': 'bar',
    'loading_absolute_dev': [0.0087652574065931, 0.017607798155186, 0.046942302421383, 0.023181234142216, 0.037581265709819, 0.058399542973894, 0.081972855693013, 0.13739751997302, 0.22494328865255, 0.072457997267975, 0.17937457962039, 0.20028701647371, 0.32879758016871, 0.31132487256175, 0.033123721672067, 0.46995736440066, 0.40568963685858, 0.41031011329949],
    'loading_absolute_average': [0.0865282072226, 0.36004175980916, 0.64290620308244, 0.96181053754412, 1.2140573074925, 1.5518582335502, 1.8666715533365, 2.225187299735, 2.6275353462274, 2.8643921085872, 3.2639803435923, 3.6793806750017, 3.9897458280376, 4.5426821766308, 5.0422080558502, 5.3663073295823, 5.9675890817607, 6.3199033694051],
    'loading_absolute_unit': 'mol/kg',
    'enthalpy_of_adsorption_dev': [0.32297213007076, 0.27111346686289, 0.46221892694121, 0.22796292600999, 0.25745750916665, 0.16795492753985, 0.27767597881486, 0.52862666600151, 0.32234806648209, 0.45234381781447, 0.54291914228464, 0.39203552750825, 0.30816422638497, 0.34176653945607, 0.36682672752821, 0.38445686895646, 0.47145696872947, 0.26207739060304],
    'enthalpy_of_adsorption_average': [-10.890383128383, -10.942039526743, -11.033822636835, -11.243288934341, -11.419890914835, -11.589942963092, -11.771446376161, -11.923225578476, -12.086625260865, -12.140682031711, -12.492937234458, -12.41730837345, -12.800464360247, -12.827214004806, -13.404393089056, -13.509415995277, -13.763287354602, -14.013218926941],
    'enthalpy_of_adsorption_unit': 'kJ/mol'
}

# Création de la figure
fig, ax1 = plt.subplots()

# Tracé de la charge absolue en fonction de la pression
ax1.errorbar(data['pressure'], data['loading_absolute_average'], yerr=data['loading_absolute_dev'], fmt='-o', color='r', label='Loading Absolute (mol/kg)')
ax1.set_xlabel(f"Pressure ({data['pressure_unit']})")
ax1.set_ylabel(f"Loading Absolute ({data['loading_absolute_unit']})", color='r')
ax1.tick_params(axis='y', labelcolor='r')

# Ajout d'un deuxième axe pour l'enthalpie d'adsorption
'''
ax2 = ax1.twinx()
ax2.errorbar(data['pressure'], data['enthalpy_of_adsorption_average'], yerr=data['enthalpy_of_adsorption_dev'], fmt='-s', color='r', label='Enthalpy of Adsorption (kJ/mol)')
ax2.set_ylabel(f"Enthalpy of Adsorption ({data['enthalpy_of_adsorption_unit']})", color='r')
ax2.tick_params(axis='y', labelcolor='r')'''

# Légendes et affichage
fig.tight_layout()
plt.title("CO2 pure isotherm at 300K")
plt.show()

# %%
import matplotlib.pyplot as plt

# Données fournies pour CO2 et CH4 (exemple)
data_CO2 = {
    'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2],
    'loading_absolute_average': [0.021916150047, 0.086852890927, 0.15377020240384, 0.22218105892092, 0.29150102981032, 0.359587202623, 0.431017617591, 0.4899477099396, 0.55270907000012, 0.62823049964356, 0.68696578176952, 0.75144796546336, 0.82284591206092, 0.89326980754528, 0.9633365509548, 1.024669302716, 1.0889891445576, 1.1474971480905],
    'loading_absolute_dev': [0.0029257587086246, 0.0046961432152114, 0.0042053747373354, 0.013539894417122, 0.013483719817968, 0.015161025526191, 0.010612737734106, 0.023253338259637, 0.034225174027897, 0.024345129716779, 0.030457062150504, 0.023879951201299, 0.031029028064904, 0.034006398430243, 0.038159936407652, 0.036657581075093, 0.024814842927216, 0.06009003342175],
    'pressure_unit': 'bar',
    'loading_absolute_unit': 'mol/kg'
}

data_CH4 = {
    'pressure': [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2],
    'loading_absolute_average': [0.015, 0.065, 0.12, 0.18, 0.24, 0.30, 0.37, 0.43, 0.48, 0.55, 0.61, 0.67, 0.73, 0.80, 0.86, 0.90, 0.95, 1.00],
    'loading_absolute_dev': [0.005, 0.010, 0.015, 0.012, 0.013, 0.014, 0.015, 0.017, 0.019, 0.020, 0.022, 0.024, 0.025, 0.027, 0.030, 0.032, 0.035, 0.038],
    'pressure_unit': 'bar',
    'loading_absolute_unit': 'mol/kg'
}

# Création de la figure
fig, ax1 = plt.subplots()

# Tracé de la charge absolue CO2 en fonction de la pression
ax1.errorbar(data_CO2['pressure'], data_CO2['loading_absolute_average'], yerr=data_CO2['loading_absolute_dev'], fmt='-o', color='b', label='CO2 Loading (mol/kg)')
# Tracé de la charge absolue CH4 en fonction de la pression
ax1.errorbar(data_CH4['pressure'], data_CH4['loading_absolute_average'], yerr=data_CH4['loading_absolute_dev'], fmt='-s', color='r', label='CH4 Loading (mol/kg)')

# Paramètres des axes
ax1.set_xlabel(f"Pressure ({data_CO2['pressure_unit']})")
ax1.set_ylabel(f"Loading Absolute ({data_CO2['loading_absolute_unit']})")

# Légendes et affichage
ax1.legend()
plt.title("CO2 and CH4 pure Isotherms at 300K")
plt.show()
